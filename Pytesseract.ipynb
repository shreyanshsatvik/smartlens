# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
from PIL import Image
img = Image.open(r"C:\Users\ADITYA SINGH\test.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1280 at 0x1FF30D58708>

# %%
img = img.convert('L')
# Now lets save that image
img.save('greyscale_noise.jpg')
# And run OCR on the greyscale image
text = pytesseract.image_to_string(Image.open('greyscale_noise.jpg')) 
print(text)
display(img)
# Out:
# NOG NOt Ma — RUginegs AS UCUp ic
#
# Every Company's nek Un Cus Seeint wk
# poundoun wute. Us 40 OKSORS Orie oe bo ,
# pesthvely to Hrs weouunde y
# fenan cok and sociale
# COMB em to TOSS
# offic cienty ote .
# To @nabw AEH.
# <PIL.Image.Image image mode=L size=960x1280 at 0x1FF30DE3E88>
